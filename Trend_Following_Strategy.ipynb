# %% [markdown]
# ## A simple trend-following strategy on one instrument. The strategy is tested on synthetic continuous NQ futures on the CME.
#
# ### Strategy Logic
# <br>
#
# $$
# \text{position} = \frac{\text{EMA of log return signal}}{\text{signal vol}\times{\text{asset vol}}}\times \text{scale}
# $$
#
# - **EMA of log return signal**:
# <br>- The **Exponential Moving Average (EMA)** of log returns is calculated over a defined look-back period.
# <br>- A **positive EMA** signals strength, indicating a **long entry**.
# <br>- A **negative EMA** signals weakness, indicating a **short entry**.
#
# - **signal vol**: signal volatility, measured using 200 EMA of absolute log returns
#
# - **asset vol**: NQ return volatility, measured using a double EMA (smoothed twice by 20 then 200 period) of absolute log returns.
#
# - **scale**: adjust the impact of volatility on the final signal calculation
#
# - **position**: the position size is inversely proportional to signal volatility and asset volatility. This dynamic sizing helps reduce exposure during volatile periods. Additionally, the position is capped by an upper/lower limit of *±pos_limit* lot.
#
# ### Parameters to Optimize:
# 1. **period**: The look-back period for the EMA of log returns, used to generate trading signals.
# 2. **scale**: Scaling factor used to adjust the target position based on volatility.

# %% [markdown]
# Loading necessary libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
from tqdm.notebook import tqdm

# %% [markdown]
# Function for reading data from a file:

# %%
def read_data(ticker):
    """
    Read logarithmic returns from file

    :ticker: ticker of continious futures
    """
    # You need to insert the path to the data file
    data = pd.read_csv(ticker+'.csv', index_col = 'date')
    #All datasets for this course are available at this link:
    #https://drive.google.com/drive/folders/1mhbVjuwNZGX9nmZuCxJStBmraF3HIzio?usp=sharing

    # Parse timestamps
    data.index = pd.to_datetime(data.index, format = "%Y-%m-%d %H:%M:%S")

    return data

# %% [markdown]
# Functions for calculating some standard statistics:

# %%
days_in_year = 365.25
# Most packages use a constant of 252 trading days per year, but here we use calendar days by adding zero returns on weekends.
# This approach is used to allow for backtesting strategies that trade a portfolio of instruments on different exchanges and in different timezones.
# Trading hours on one exchange may fall on weekends on another.

def Return(rets):
    """
    Annual return estimate

    :rets: daily returns of the strategy
    """
    return np.mean(rets)*days_in_year


def Volatility(rets):
    """
    Estimation of annual volatility

    :rets: daily returns of the strategy
    """
    return np.std(rets)*np.sqrt(days_in_year)


def SharpeRatio(rets):
    """
    Estimating the annual Sharpe ratio

    :rets: daily returns of the strategy
    """
    volatility = Volatility(rets)
    if (volatility>0):
        return Return(rets)/volatility
    else:
        return float('NaN')

def statistics_calc(rets, bh, name = '_', plot = False):
    """
    Draws a graph of portfolio equity and calculates annual Sharpe ratios, profitability and volatility

    :rets: daily returns of the strategy
    """
    sharpe = SharpeRatio(rets)
    ret = Return(rets)
    vol = Volatility(rets)
    if plot:
        plt.plot(rets.cumsum(), label = 'strategy')
        plt.plot(bh.cumsum(), label = 'buy & hold')
        plt.xlabel('t')
        plt.legend()
        print('Sharpe ratio = %0.2f'%sharpe)
        print('Annual Return = %0.2f'%ret)
        print('Annual Std = %0.2f'%vol)
    return  pd.DataFrame([[sharpe, ret, vol]], columns = ['Sharpe ratio', 'Annual return', 'Volatility'], index = [name])

# %% [markdown]
# Reading data:

# %%
data = read_data('NQ')

# Let's draw graphs
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(data)
ax1.set_ylabel('log_ret')

ax2.plot(data.cumsum())
ax2.set_yticks([])
ax2.set_ylabel('cumsum(log_ret)')
_ = ax2.set_xlabel('t')

# %% [markdown]
# Prepare train and test samples:

# %%
in_sample_start = '2018-01-01'
in_sample_end = '2022-01-01'

train = data[in_sample_start:in_sample_end]
test = data[in_sample_end:]
train_test = data[in_sample_start:]

# %% [markdown]
# Function for strategy logic and backtest calculation:

# %%
def strategy_backtest(data, params, plot = False, in_sample_end = '', slippage = 0.00001):
    """
    Strategy backtest calculation
    Example call:
    strategy_bactest(test, [period, scale])

    :data: dataframe with log returns
    :params: list of strategy parameters
    :plot: if True than equity curve is plotted
    :in_sample_end: string in format "%Y-%m-%d" with timestamp of in_sample_end. Only used on charts
    :slippage: slippage per trade

    :return: statistics and equity curve
    """

    # Strategy parameters that we will optimize
    period = params[0]
    scale = params[1]

    # Calculation of target position:

    features = pd.DataFrame(index = data.index)

    # We calculate the exponential moving average of increments:
    features['signal'] = data['log_ret'].ewm(period).mean()

    # Estimating signal volatility using exponential moving average
    features['absSignal'] = np.abs(features['signal']).shift(1)
    features['signal_vol'] = features['absSignal'].ewm(200).mean()+0.000000001 #0.000000001 is to prevent value=0 that could cause Devision by Zero error

    # Estimating asset volatility using double exponential moving average:
    features['absRet'] = np.abs(data['log_ret'])
    features['EmaAbsRet'] = features['absRet'].ewm(20).mean().shift(1)*np.sqrt(20)
    features['vol'] = features['EmaAbsRet'].ewm(200).mean()*np.sqrt(200)+0.000000001

    # Calc target position:
    features['position'] = ((features['signal']/features['signal_vol']/features['vol']*scale).shift(1)).fillna(0).astype(int)

    # We remove looking into the future
    # (we cannot execute the order at the same price at which the signal was calculated. We need to take the price of the next bar)
    features['position'] = features['position'].shift(1)

    # We trade whole lots
    features['position'] = features['position'].fillna(0).astype(int)

    # Maximum position limit
    pos_limit = 1
    features.loc[features.index[features['position']>pos_limit], 'position'] = pos_limit
    features.loc[features.index[features['position']<-pos_limit], 'position'] = -pos_limit

    # We calculate the equity curve and convert it to a daily timeframe to calculate basic statistics
    eq =  (data['log_ret'] * features['position']                        # Apply the position to log returns to compute strategy returns
          - slippage * features['position'].diff().abs()                 # Subtract trading costs and slippage based on position changes (slippage)
          ).fillna(0).resample('1D').agg('sum')                          # Resample to daily frequency by summing log returns (log returns are additive over time)

    bh = data['log_ret'].fillna(0).resample('1D').agg('sum') # buy-and-hold benchmark

    # We calculate statistics and save the result
    stats = statistics_calc(eq, bh, name = "{0}_{1}".format(period, scale), plot = plot)
    stats['period'] = period
    stats['scale'] = scale

    # Draw a graph of position changes, if necessary
    if plot:
        if in_sample_end  != '':
            plt.axvline(x = datetime.datetime.strptime(in_sample_end, "%Y-%m-%d").date(), color = 'red')
        plt.figure()
        position_to_plot = features['position'][-10000:]
        plt.plot(np.arange(len(position_to_plot)), position_to_plot)
        plt.title('position')
        plt.xlabel('t')

    return stats, eq

# %% [markdown]
# Grid for strategy parameters:

# %%
periods = (np.logspace(1.0, 4.0, num = 20)).astype(int)
scales = np.logspace(-2.0, 0.0, num = 20).round(4)

print('Periods: ',periods)
print('Scales: ', scales)
# Out:
# Periods:  [   10    14    20    29    42    61    88   127   183   263   379   545
#    784  1128  1623  2335  3359  4832  6951 10000]
# Scales:  [0.01   0.0127 0.0162 0.0207 0.0264 0.0336 0.0428 0.0546 0.0695 0.0886
#  0.1129 0.1438 0.1833 0.2336 0.2976 0.3793 0.4833 0.6158 0.7848 1.    ]

# %% [markdown]
# Searching through the grid of parameters (can take quite a long time):

# %%
stats = pd.DataFrame()

for period in tqdm(periods):
    for scale in scales:
        stats_current, _ = strategy_backtest(train, [period, scale])
        if stats.shape[0] == 0:
            stats = stats_current
        else:
            stats = pd.concat([stats, stats_current])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# Optimization results on heatmap:

# %%
stats_pivot = stats.pivot(index = 'period', columns = 'scale', values = 'Sharpe ratio')

plt.imshow(stats_pivot, aspect = 'auto', interpolation = 'none')
plt.xticks(np.arange(len(scales)), scales, rotation = 90)
plt.yticks(np.arange(len(periods)), periods)
plt.title('Sharpe coef')
plt.xlabel('Scale')
plt.ylabel('Period')

_ = plt.colorbar()

# %% [markdown]
# Best set of parameters:

# %%
temp = stats_pivot.values
amax = temp.argmax()
row, col = (amax//temp.shape[1], amax%temp.shape[1])
print('Sharpe ratio = ', stats_pivot.iloc[row, col])
print('Period = ', stats_pivot.index[row], 'Scale = ', stats_pivot.columns[col])

best_is_stats = stats.sort_values('Sharpe ratio', ascending = False).iloc[0]
# Out:
# Sharpe ratio =  1.9170259174787587
# Period =  183 Scale =  0.0264

# %% [markdown]
# We calculate equity on data that includes a test period:

# %%
_, eq = strategy_backtest(train_test, [best_is_stats['period'].astype(int), best_is_stats['scale']], True, in_sample_end)
# Out:
# Sharpe ratio = 1.69
# Annual Return = 0.19
# Annual Std = 0.12

# %% [markdown]
# Calculate statistics on test data:

# %%
statistics_calc(eq[in_sample_end:], test, name = "{0}_{1}".format(period, scale), plot = True)
_=plt.xticks(rotation = 45)
# Out:
# Sharpe ratio = 1.38
# Annual Return = 0.17
# Annual Std = 0.12

# %% [markdown]
# Creating a report using pyfolio

# %%
# !pip install pyfolio_reloaded
# Out:
# Requirement already satisfied: pyfolio_reloaded in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (0.9.5)
# Requirement already satisfied: ipython>=3.2.3 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (8.12.3)
# Requirement already satisfied: matplotlib>=1.4.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (3.7.2)
# Requirement already satisfied: numpy>=1.11.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (1.24.4)
# Requirement already satisfied: pandas>=0.18.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (2.0.3)
# Requirement already satisfied: pytz>=2014.10 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (2023.3.post1)
# Requirement already satisfied: scipy>=0.14.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.16.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (1.3.0)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.8 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pyfolio_reloaded) (0.5.10)
# Requirement already satisfied: bottleneck>=1.3.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from empyrical-reloaded>=0.5.8->pyfolio_reloaded) (1.3.7)
# Requirement already satisfied: peewee<3.17.4 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from empyrical-reloaded>=0.5.8->pyfolio_reloaded) (3.17.3)
# Requirement already satisfied: backcall in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.2.0)
# Requirement already satisfied: decorator in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (3.0.40)
# Requirement already satisfied: pygments>=2.4.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (2.16.1)
# Requirement already satisfied: stack-data in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (5.13.0)
# Requirement already satisfied: typing-extensions in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (4.13.1)
# Requirement already satisfied: pexpect>4.3 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (4.8.0)
# Requirement already satisfied: appnope in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from ipython>=3.2.3->pyfolio_reloaded) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (10.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from matplotlib>=1.4.0->pyfolio_reloaded) (6.1.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pandas>=0.18.1->pyfolio_reloaded) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from scikit-learn>=0.16.1->pyfolio_reloaded) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from scikit-learn>=0.16.1->pyfolio_reloaded) (2.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=1.4.0->pyfolio_reloaded) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio_reloaded) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio_reloaded) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=3.2.3->pyfolio_reloaded) (0.2.10)
# Requirement already satisfied: six>=1.5 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->pyfolio_reloaded) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio_reloaded) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio_reloaded) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/nuohanluo/anaconda3/envs/AI_torch/lib/python3.8/site-packages (from stack-data->ipython>=3.2.3->pyfolio_reloaded) (0.2.2)

# %% [markdown]
# Additional exercises and research topics:
#
# 1.  Optimize all strategy parameters. Study the sensitivity of strategy to small changes in parameters.
# 2.  Test the strategy on other timeframes and instruments.
# 3.  Try using other parametric families of functions (trend-following indicators) to form the target position.
# 4.  Implement a walk-forward optimization scheme.
# 5.  Construct a portfolio of strategies.
